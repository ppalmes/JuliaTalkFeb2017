# %% [markdown]
# # [DFA Preliminaries](./DFASlide.pdf)

# %%
logis(x) = 1 ./ (1 .+ exp(-x))
dlogis(x) = logis(x) .* (1 .- logis(x))
# Out:
# WARNING: Method definition logis(Any) in module Main at In[2]:3 overwritten at In[10]:1.
# WARNING: Method definition dlogis(Any) in module Main at In[2]:4 overwritten at In[10]:2.
# dlogis (generic function with 1 method)

# %%
inp = [1 1 ; 0 1 ; 1 0 ; 0 0]'
# Out:
# 2×4 Array{Int64,2}:
#  1  0  1  0
#  1  1  0  0

# %%
out = [0 1 1 0]
# Out:
# 1×4 Array{Int64,2}:
#  0  1  1  0

# %%
y=zeros(size(out))
# Out:
# 1×4 Array{Float64,2}:
#  0.0  0.0  0.0  0.0

# %%
n_hidden = 10; # Number of hidden units
num_iterations = 1000; #Number of learning steps
trials = 4000;

# %%
w1 = randn(n_hidden,size(inp,1))
# Out:
# 10×2 Array{Float64,2}:
#  -0.0137424   0.0793102
#  -1.21523     1.3835
#  -1.00232    -0.26536
#  -1.53517     1.13683
#   1.98658    -0.633892
#   0.703696   -0.915932
#   2.12164    -0.691851
#  -0.425324    1.19837
#  -0.596488    0.959852
#  -1.93161    -0.490768

# %%
w2 = randn(n_hidden,n_hidden);

# %%
w3 = randn(size(out,1),n_hidden)
# Out:
# 1×10 Array{Float64,2}:
#  0.27572  -0.798905  -0.110264  0.742285  …  0.287355  0.704697  1.25104

# %%
logis(w3 * (logis(w2 * (logis(w1 * inp)))))
# Out:
# 1×4 Array{Float64,2}:
#  0.463856  0.405243  0.511414  0.43549

# %%
bp_w1=w1
bp_w2=w2
bp_w3=w3
# Out:
# 1×10 Array{Float64,2}:
#  0.27572  -0.798905  -0.110264  0.742285  …  0.287355  0.704697  1.25104

# %%
B1=rand(n_hidden,1)
B2=rand(n_hidden,1)
# Out:
# 10×1 Array{Float64,2}:
#  0.935558
#  0.737461
#  0.880536
#  0.465581
#  0.54508
#  0.415001
#  0.899647
#  0.297021
#  0.451022
#  0.00329869

# %%
a1 = w1 * inp
z1 = logis(a1)
a2 = w2 * z1
z2 = logis(a2)
ay = w3 * z2
y .= logis(ay)
# Out:
# 1×4 Array{Float64,2}:
#  0.463856  0.405243  0.511414  0.43549

# %%
err=y-out
# Out:
# 1×4 Array{Float64,2}:
#  0.463856  -0.594757  -0.488586  0.43549

# %%
d_a1 = (B1.*err) .* dlogis(a1)
# Out:
# 10×4 Array{Float64,2}:
#  0.0403464  -0.0517065  -0.0425411  0.0379198
#  0.0333898  -0.0276407  -0.0249974  0.0315704
#  0.0750384  -0.137889   -0.0905644  0.102752
#  0.0882721  -0.0866041  -0.0564141  0.0862052
#  0.0547345  -0.0973745  -0.037464   0.0787044
#  0.0785708  -0.0831821  -0.0741327  0.0745998
#  0.0198132  -0.0362435  -0.0127977  0.0298424
#  0.020952   -0.0221367  -0.0244128  0.0227588
#  0.0981744  -0.104184   -0.0978908  0.0952468
#  0.0343408  -0.138569   -0.0534299  0.107695

# %%
d_a2 = (B2*err) .* dlogis(a2)
# Out:
# 10×4 Array{Float64,2}:
#  0.108459     -0.13461      -0.114242    0.0986703
#  0.0852576    -0.0968743    -0.0837592   0.050092
#  0.0475307    -0.112345     -0.0772581   0.0957494
#  0.00591929   -0.00707256   -0.00786305  0.00584865
#  0.0606902    -0.0361952    -0.0658159   0.0409281
#  0.0476881    -0.0573742    -0.0506336   0.0430163
#  0.0503498    -0.0900813    -0.0624694   0.0756741
#  0.0254395    -0.0205611    -0.0346512   0.0209015
#  0.0393832    -0.0477032    -0.0493248   0.0440145
#  0.000173004  -0.000395432  -0.00022703  0.000311786

# %%
dw1 = -d_a1 * inp'
# Out:
# 10×2 Array{Float64,2}:
#   0.00219468    0.0113601
#  -0.00839245   -0.00574915
#   0.015526      0.062851
#  -0.0318579    -0.00166797
#  -0.0172706     0.04264
#  -0.0044381     0.00461132
#  -0.00701551    0.0164304
#   0.00346084    0.00118474
#  -0.000283543   0.00600959
#   0.0190891     0.104228

# %%
dw2 = -d_a2 * z1'
# Out:
# 10×10 Array{Float64,2}:
#   0.0213589     0.0256469     0.0159405    …   0.0245977     0.00740025
#   0.0228769     0.0253653     0.0207628        0.0244603     0.015393
#   0.0243436     0.0338657     0.0111906        0.0327629     0.00068993
#   0.00159999    0.00132137    0.000956408      0.00149081    0.000274143
#  -0.000306893  -0.00935912   -0.000413927     -0.00671561   -0.00333497
#   0.00883332    0.0101039     0.00651439   …   0.00983204    0.00280065
#   0.0140089     0.0211912     0.00697496       0.0197868     0.000172239
#   0.00430723    0.000128909   0.00218918       0.00171751   -0.000330402
#   0.00694566    0.00607386    0.00329042       0.00677375   -0.000859621
#   7.30575e-5    0.000118452   3.86959e-5       0.000108623   8.89646e-6

# %%
dw3 = -err * z2'
# Out:
# 1×10 Array{Float64,2}:
#  0.106774  0.137502  0.0274758  …  0.0709085  0.0385583  0.0503939

# %%
w1 = w1 + dw1
w2 = w2 + dw2
w3 = w3 + dw3
# Out:
# 1×10 Array{Float64,2}:
#  0.382494  -0.661403  -0.082788  0.749372  …  0.358264  0.743256  1.30143

# %%
bp_a1 = bp_w1*inp
bp_z1 = logis(bp_a1)
bp_a2 = bp_w2 * bp_z1
bp_z2 = logis(bp_a2)
bp_ay = bp_w3 * bp_z2
bp_y = logis(bp_ay)
bp_err = bp_y - out
# Out:
# 1×4 Array{Float64,2}:
#  0.463856  -0.594757  -0.488586  0.43549

# %%
bp_d3 = (bp_err) .* dlogis(bp_ay)
# Out:
# 1×4 Array{Float64,2}:
#  0.115358  -0.143349  -0.122083  0.10706

# %%
bp_d2 = (bp_w3' * bp_d3) .* dlogis(bp_a2)
# Out:
# 10×4 Array{Float64,2}:
#   0.0079493   -0.00956158  -0.00841273   0.00714882
#  -0.0229696    0.0252941    0.0226726   -0.0133406
#  -0.00148021   0.00339074   0.00241737  -0.00294762
#   0.00234698  -0.00271774  -0.00313242   0.00229235
#  -0.0362565    0.020956     0.0395046   -0.0241699
#   0.0364077   -0.0424513   -0.0388393    0.032464
#  -0.00374663   0.00649632   0.00467045  -0.00556641
#   0.00612077  -0.00479438  -0.00837653   0.00497116
#   0.0153032   -0.0179642   -0.0192568    0.0169064
#   0.0163173   -0.0361455   -0.0215142    0.0290693

# %%
bp_d1 = (bp_w2' * bp_d2) .* dlogis(bp_a1)
# Out:
# 10×4 Array{Float64,2}:
#  -0.0113463     0.0150518    0.012862     -0.0116155
#   0.00542559   -0.00269393  -0.00444425    0.00442898
#   0.00117183   -0.0032103   -0.00259902    0.00668089
#  -0.0154322     0.00634901   0.0115385    -0.0138948
#  -0.00762883    0.0153349    0.00699668   -0.017875
#  -0.00346226    0.00187734   0.00138402    0.00162124
#   0.00954023   -0.00692292  -0.00650987    0.00932828
#   0.000173172   0.00208529   0.000866066  -0.00305784
#  -0.0156408     0.010318     0.0167327    -0.0124204
#  -0.00451475    0.00717038   0.00698325   -0.00630138

# %%
bp_w1 .-= (inp * bp_d1')'
bp_w2 .-= (z1 * bp_d2')'
bp_w3 .-= (z2 * bp_d3')'
# Out:
# 1×10 Array{Float64,2}:
#  -0.380241  0.449824  -0.0540714  …  -0.799494  -2.06867  -0.959109

# %%
e_store(ii,jj) = sum(abs(err))
bp_e_store(ii,jj) = sum(abs(bp_error))

# %%
nprocs()==1 && addprocs()

@everywhere logis(x) = 1 ./ (1 .+ exp(-x))
@everywhere dlogis(x) = logis(x) .* (1 .- logis(x))

@everywhere function dfa!(w1,w2,w3,B1,B2,inp,out)
    a1 = w1 * inp
    z1 = logis(a1)
    a2 = w2 * z1
    z2 = logis(a2)
    ay = w3 * z2
    y = logis(ay)
    err = y - out
    d_a1 = (B1.*err) .* dlogis(a1) 
    d_a2 = (B2.*err) .* dlogis(a2) 
    w1 .-= d_a1 * inp'
    w2 .-= d_a2 * z1'
    w3 .-= err * z2'
    return Dict("output"=>y,"err"=>err)
end

@everywhere function bp!(bp_w1,bp_w2,bp_w3,inp,out)
    bp_a1 = bp_w1*inp
    bp_z1 = logis(bp_a1)
    bp_a2 = bp_w2 * bp_z1
    bp_z2 = logis(bp_a2)
    bp_ay = bp_w3 * bp_z2
    bp_y = logis(bp_ay)
    bp_err = bp_y - out
    bp_d_a3 = (bp_err) .* dlogis(bp_ay)
    bp_d_a2 = (bp_w3' * bp_d_a3) .* dlogis(bp_a2)
    bp_d_a1 = (bp_w2' * bp_d_a2) .* dlogis(bp_a1)
    bp_w1 .-= bp_d_a1 * inp'
    bp_w2 .-= bp_d_a2 * bp_z1'
    bp_w3 .-= bp_d_a3 * bp_z2'
    return Dict("output"=>bp_y,"err"=>bp_err)
end
# Out:
# WARNING: Method definition logis(Any) in module Main at In[44]:3 overwritten at In[46]:3.
# WARNING: Method definition logis(Any) in module Main at In[44]:3 overwritten at In[46]:3.
# WARNING: Method definition logis(Any) in module Main at In[44]:3 overwritten at In[46]:3.
# WARNING: Method definition logis(Any) in module Main at In[44]:3 overwritten at In[46]:3.
# WARNING: Method definition logis(Any) in module Main at In[44]:3 overwritten at In[46]:3.
# WARNING: Method definition dlogis(Any) in module Main at In[44]:4 overwritten at In[46]:4.
# WARNING: Method definition dlogis(Any) in module Main at In[44]:4 overwritten at In[46]:4.
# WARNING: Method definition dlogis(Any) in module Main at In[44]:4 overwritten at In[46]:4.
# WARNING: Method definition dlogis(Any) in module Main at In[44]:4 overwritten at In[46]:4.
# WARNING: Method definition dlogis(Any) in module Main at In[44]:4 overwritten at In[46]:4.
# WARNING: Method definition dfa!(Any, Any, Any, Any, Any, Any, Any) in module Main at In[44]:7 overwritten at In[46]:7.
# WARNING: Method definition dfa!(Any, Any, Any, Any, Any, Any, Any) in module Main at In[44]:7 overwritten at In[46]:7.
# WARNING: Method definition dfa!(Any, Any, Any, Any, Any, Any, Any) in module Main at In[44]:7 overwritten at In[46]:7.
# WARNING: Method definition dfa!(Any, Any, Any, Any, Any, Any, Any) in module Main at In[44]:7 overwritten at In[46]:7.
# WARNING: Method definition dfa!(Any, Any, Any, Any, Any, Any, Any) in module Main at In[44]:7 overwritten at In[46]:7.
# WARNING: Method definition bp!(Any, Any, Any, Any, Any) in module Main at In[44]:23 overwritten at In[46]:23.
# WARNING: Method definition bp!(Any, Any, Any, Any, Any) in module Main at In[44]:23 overwritten at In[46]:23.
# WARNING: Method definition bp!(Any, Any, Any, Any, Any) in module Main at In[44]:23 overwritten at In[46]:23.
# WARNING: Method definition bp!(Any, Any, Any, Any, Any) in module Main at In[44]:23 overwritten at In[46]:23.
# WARNING: Method definition bp!(Any, Any, Any, Any, Any) in module Main at In[44]:23 overwritten at In[46]:23.

# %%
inp = [1 1 ; 0 1 ; 1 0 ; 0 0]'
out = [0 1 1 0]
y=zeros(size(out))
n_hidden = 15; # Number of hidden units
num_iterations = 1000; #Number of learning steps
trials = 50;

e_store = SharedArray(Float64,(num_iterations,trials))
bp_e_store = SharedArray(Float64,(num_iterations,trials))
y_store = SharedArray(Float64,(size(out,2),num_iterations))
bp_y_store = SharedArray(Float64,(size(out,2),num_iterations))

@elapsed @sync @parallel for jj = 1:trials
    w1 = randn(n_hidden,size(inp,1))
    w2 = randn(n_hidden,n_hidden)
    w3 = randn(size(out,1),n_hidden)
          
    B1=rand(n_hidden,1)
    B2=rand(n_hidden,1)    
    
    bp_w1 = randn(n_hidden,size(inp,1))
    bp_w2 = randn(n_hidden,n_hidden)
    bp_w3 = randn(size(out,1),n_hidden) 
    
    for ii = 1:num_iterations       
        dfa_res = dfa!(w1,w2,w3,B1,B2,inp,out)       
        bp_res = bp!(bp_w1,bp_w2,bp_w3,inp,out)       
        if jj == 1
            y_store[:,ii] = dfa_res["output"]'
            bp_y_store[:,ii] = bp_res["output"]'
        end       
        e_store[ii,jj] = sum(abs(dfa_res["err"]))
        bp_e_store[ii,jj] = sum(abs(bp_res["err"]))
    end
end
# Out:
# 2.195718059

# %%
using Plots
l = @layout [
    a b
    c d
]

gr()
p1=plot(y_store',label=["1,1" "0,1" "1,0" "0,0"],title="DFA")
p2=plot(bp_y_store',label=["1,1" "0,1" "1,0" "0,0"],title="BP")
p3=plot([e_store[:,1] bp_e_store[:,1]],label=["DFA" "BP"],title="First Trial")
p4=plot([mean(e_store,2) mean(bp_e_store,2)],label=["DFA" "BP"],title="Mean Error")
plot(p1,p2,p3,p4,layout=l)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 39.4926,184.952 296.063,184.952 296.063,23.3815 39.4926,23.3815
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="23" width="257" height="162"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   103.443,182.528 103.443,25.805
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   167.649,182.528 167.649,25.805
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   231.856,182.528 231.856,25.805
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   296.063,182.528 296.063,25.805
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   43.3411,144.966 292.214,144.966
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   43.3411,104.387 292.214,104.387
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   43.3411,63.8073 292.214,63.8073
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.4926,184.952 296.063,184.952
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   103.443,184.952 103.443,182.528
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   167.649,184.952 167.649,182.528
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   231.856,184.952 231.856,182.528
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   296.063,184.952 296.063,182.528
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.4926,184.952 39.4926,23.3815
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.4926,144.966 43.3411,144.966
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.4926,104.387 43.3411,104.387
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.4926,63.8073 43.3411,63.8073
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 103.443, 196.952)" x="103.443" y="196.952">250</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 167.649, 196.952)" x="167.649" y="196.952">500</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 231.856, 196.952)" x="231.856" y="196.952">750</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 296.063, 196.952)" x="296.063" y="196.952">1000</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.2926, 149.466)" x="38.2926" y="149.466">0.25</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.2926, 108.887)" x="38.2926" y="108.887">0.50</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 38.2926, 68.3073)" x="38.2926" y="68.3073">0.75</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 167.778, 18)" x="167.778" y="18">DFA</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#0099ff; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   39.4926,124.63 39.7494,44.9305 40.0062,179.505 40.263,34.6191 40.5199,182.793 40.7767,36.8796 41.0335,183.096 41.2904,30.5336 41.5472,183.421 41.804,29.464
#   42.0608,182.979 42.3177,27.9865 42.5745,182.553 42.8313,27.083 43.0881,182.356 43.345,26.6773 43.6018,182.305 43.8586,26.4603 44.1155,182.34 44.3723,26.29
#   44.6291,182.442 44.8859,26.1224 45.1428,182.588 45.3996,25.9368 45.6564,182.736 45.9132,25.727 46.1701,182.844 46.4269,25.5031 46.6837,182.887 46.9406,25.2837
#   47.1974,182.861 47.4542,25.0843 47.711,182.778 47.9679,24.9117 48.2247,182.653 48.4815,24.7661 48.7383,182.494 48.9952,24.6439 49.252,182.31 49.5088,24.5406
#   49.7657,182.105 50.0225,24.4518 50.2793,181.88 50.5361,24.3735 50.793,181.636 51.0498,24.3026 51.3066,181.373 51.5634,24.2367 51.8203,181.092 52.0771,24.1743
#   52.3339,180.794 52.5908,24.1142 52.8476,180.481 53.1044,24.0564 53.3612,180.154 53.6181,24.0012 53.8749,179.819 54.1317,23.9495 54.3885,179.481 54.6454,23.9025
#   54.9022,179.148 55.159,23.8613 55.4159,178.831 55.6727,23.8271 55.9295,178.543 56.1863,23.8011 56.4432,178.298 56.7,23.7843 56.9568,178.114 57.2136,23.7779
#   57.4705,178.007 57.7273,23.7838 57.9841,177.991 58.241,23.8047 58.4978,178.076 58.7546,23.8453 59.0114,178.264 59.2683,23.9136 59.5251,178.545 59.7819,24.0239
#   60.0387,178.893 60.2956,24.2027 60.5524,179.262 60.8092,24.503 61.0661,179.589 61.3229,25.0408 61.5797,179.792 61.8365,26.0958 62.0934,179.792 62.3502,28.3876
#   62.607,179.57 62.8638,33.6043 63.1207,179.256 63.3775,44.2356 63.6343,178.852 63.8912,62.2515 64.148,177.767 64.4048,90.4433 64.6616,174.726 64.9185,125.424
#   65.1753,168.545 65.4321,148.927 65.6889,162.919 65.9458,157.453 66.2026,161.141 66.4594,160.336 66.7163,161.451 66.9731,161.727 67.2299,162.303 67.4867,162.744
#   67.7436,163.209 68.0004,163.644 68.2572,164.068 68.514,164.476 68.7709,164.87 69.0277,165.251 69.2845,165.62 69.5414,165.976 69.7982,166.321 70.055,166.654
#   70.3118,166.978 70.5687,167.291 70.8255,167.594 71.0823,167.888 71.3391,168.174 71.596,168.45 71.8528,168.719 72.1096,168.98 72.3665,169.233 72.6233,169.479
#   72.8801,169.719 73.1369,169.951 73.3938,170.177 73.6506,170.397 73.9074,170.611 74.1642,170.819 74.4211,171.022 74.6779,171.22 74.9347,171.412 75.1916,171.6
#   75.4484,171.783 75.7052,171.961 75.962,172.135 76.2189,172.304 76.4757,172.47 76.7325,172.632 76.9893,172.789 77.2462,172.943 77.503,173.094 77.7598,173.241
#   78.0167,173.385 78.2735,173.525 78.5303,173.663 78.7871,173.797 79.044,173.929 79.3008,174.057 79.5576,174.183 79.8144,174.307 80.0713,174.427 80.3281,174.546
