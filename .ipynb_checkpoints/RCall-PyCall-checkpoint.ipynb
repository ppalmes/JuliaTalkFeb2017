# %%
using RCall

# %%
R"library(ggplot2)"
# Out:
# RCall.RObject{RCall.StrSxp}
# [1] "ggplot2"   "stats"     "graphics"  "grDevices" "utils"     "datasets"
# [7] "methods"   "base"

# %%
R"ggplot(iris,aes(Sepal.Length,Petal.Width,color=Species))+geom_point()"
# Out:
# RCall.RObject{RCall.VecSxp}

# %%
x=rand(10)
# Out:
# 10-element Array{Float64,1}:
#  0.140237
#  0.355252
#  0.96307
#  0.32518
#  0.549361
#  0.497484
#  0.177051
#  0.62146
#  0.817167
#  0.374669

# %%
R"t.test($x)"
# Out:
# RCall.RObject{RCall.VecSxp}
#
# 	One Sample t-test
#
# data:  `#JL`$x
# t = 5.7623, df = 9, p-value = 0.0002721
# alternative hypothesis: true mean is not equal to 0
# 95 percent confidence interval:
#  0.2928329 0.6713534
# sample estimates:
# mean of x
# 0.4820932

# %%
R"x=runif(10)"
# Out:
# RCall.RObject{RCall.RealSxp}
#  [1] 0.08932067 0.53461755 0.49601599 0.74007609 0.13695711 0.97467497
#  [7] 0.65182079 0.34752921 0.68617794 0.18537946

# %%
@rget(x)
# Out:
# 10-element Array{Float64,1}:
#  0.0893207
#  0.534618
#  0.496016
#  0.740076
#  0.136957
#  0.974675
#  0.651821
#  0.347529
#  0.686178
#  0.185379

# %%
R"x"
# Out:
# RCall.RObject{RCall.RealSxp}
#  [1] 0.08932067 0.53461755 0.49601599 0.74007609 0.13695711 0.97467497
#  [7] 0.65182079 0.34752921 0.68617794 0.18537946

# %%
x=rand(100)
# Out:
# 100-element Array{Float64,1}:
#  0.602657
#  0.0584383
#  0.430324
#  0.487707
#  0.555087
#  0.812544
#  0.995568
#  0.687594
#  0.836029
#  0.623102
#  0.427251
#  0.524646
#  0.140349
#  ⋮
#  0.398605
#  0.670599
#  0.411174
#  0.240228
#  0.128388
#  0.498746
#  0.261046
#  0.63705
#  0.73494
#  0.345131
#  0.112551
#  0.00424796

# %%
@rput(x)
# Out:
# 100-element Array{Float64,1}:
#  0.602657
#  0.0584383
#  0.430324
#  0.487707
#  0.555087
#  0.812544
#  0.995568
#  0.687594
#  0.836029
#  0.623102
#  0.427251
#  0.524646
#  0.140349
#  ⋮
#  0.398605
#  0.670599
#  0.411174
#  0.240228
#  0.128388
#  0.498746
#  0.261046
#  0.63705
#  0.73494
#  0.345131
#  0.112551
#  0.00424796

# %%
R"x"
# Out:
# RCall.RObject{RCall.RealSxp}
#   [1] 0.602657292 0.058438269 0.430324117 0.487706996 0.555087131 0.812543637
#   [7] 0.995568300 0.687593623 0.836028659 0.623102437 0.427251052 0.524645695
#  [13] 0.140348963 0.529882935 0.822384087 0.435922003 0.679784538 0.741823043
#  [19] 0.804927506 0.509326056 0.017223163 0.900252400 0.379063974 0.114625684
#  [25] 0.584161617 0.984535545 0.400627185 0.795531534 0.218168053 0.460565322
#  [31] 0.829223966 0.670301134 0.956364421 0.086618929 0.556142156 0.136304479
#  [37] 0.124983573 0.365472051 0.941809780 0.308307694 0.338564024 0.310143601
#  [43] 0.990074713 0.712372138 0.739964068 0.182874018 0.857561718 0.986751218
#  [49] 0.556359405 0.383727609 0.015124529 0.933655042 0.572092698 0.600909115
#  [55] 0.473506556 0.661932520 0.790696670 0.388076786 0.675203907 0.337204883
#  [61] 0.485455688 0.174305779 0.365606368 0.983723625 0.525728763 0.293153170
#  [67] 0.615503654 0.961695907 0.668830283 0.502783634 0.465911953 0.337268720
# ...

# %%
R"a=iris"
# Out:
# RCall.RObject{RCall.VecSxp}
#     Sepal.Length Sepal.Width Petal.Length Petal.Width    Species
# 1            5.1         3.5          1.4         0.2     setosa
# 2            4.9         3.0          1.4         0.2     setosa
# 3            4.7         3.2          1.3         0.2     setosa
# 4            4.6         3.1          1.5         0.2     setosa
# 5            5.0         3.6          1.4         0.2     setosa
# 6            5.4         3.9          1.7         0.4     setosa
# 7            4.6         3.4          1.4         0.3     setosa
# 8            5.0         3.4          1.5         0.2     setosa
# 9            4.4         2.9          1.4         0.2     setosa
# 10           4.9         3.1          1.5         0.1     setosa
# 11           5.4         3.7          1.5         0.2     setosa
# 12           4.8         3.4          1.6         0.2     setosa
# 13           4.8         3.0          1.4         0.1     setosa
# ...

# %%
@rget(a)
# Out:
# 150×5 DataFrames.DataFrame
# │ Row │ Sepal.Length │ Sepal.Width │ Petal.Length │ Petal.Width │ Species     │
# ├─────┼──────────────┼─────────────┼──────────────┼─────────────┼─────────────┤
# │ 1   │ 5.1          │ 3.5         │ 1.4          │ 0.2         │ "setosa"    │
# │ 2   │ 4.9          │ 3.0         │ 1.4          │ 0.2         │ "setosa"    │
# │ 3   │ 4.7          │ 3.2         │ 1.3          │ 0.2         │ "setosa"    │
# │ 4   │ 4.6          │ 3.1         │ 1.5          │ 0.2         │ "setosa"    │
# │ 5   │ 5.0          │ 3.6         │ 1.4          │ 0.2         │ "setosa"    │
# │ 6   │ 5.4          │ 3.9         │ 1.7          │ 0.4         │ "setosa"    │
# │ 7   │ 4.6          │ 3.4         │ 1.4          │ 0.3         │ "setosa"    │
# │ 8   │ 5.0          │ 3.4         │ 1.5          │ 0.2         │ "setosa"    │
# │ 9   │ 4.4          │ 2.9         │ 1.4          │ 0.2         │ "setosa"    │
# ...

# %%
using PyCall

# %%
@pyimport math
math.sin(π/4)
# Out:
# 0.7071067811865475

# %%
@pyimport numpy.random as nr
nr.rand(3,4)
# Out:
# 3×4 Array{Float64,2}:
#  0.692298  0.970907  0.411606  0.302314
#  0.605386  0.337565  0.39397   0.55585
#  0.11288   0.325619  0.925717  0.75273

# %%
using PyPlot
using PyCall
@pyimport matplotlib.pyplot as pt
# Out:
# /Users/ppalmes/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
x = linspace(0,2π,1000); y = sin(3x + 4cos(2x));
pt.plot(x, y, color="red", linewidth=2.0, linestyle="--")
pt.show()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x3207b7e50>)

# %%
a=rand(10,5)
# Out:
# 10×5 Array{Float64,2}:
#  0.344322   0.148548  0.293015   0.472926   0.299975
#  0.486186   0.151171  0.0986212  0.745034   0.500329
#  0.354097   0.142779  0.188027   0.370743   0.00831857
#  0.432562   0.450563  0.925059   0.542051   0.71396
#  0.0350965  0.727024  0.0290764  0.315126   0.547878
#  0.922298   0.886624  0.928064   0.542284   0.430975
#  0.679815   0.337391  0.527174   0.0127035  0.755419
#  0.927304   0.870347  0.219858   0.978287   0.975578
#  0.0508781  0.498822  0.697498   0.0782399  0.350194
#  0.797926   0.561419  0.132752   0.201893   0.457295

# %%
py"sum($a)"
# Out:
# 5-element Array{Float64,1}:
#  5.03049
#  4.77469
#  4.03914
#  4.25929
#  5.03992

# %%
sum(a,1)
# Out:
# 1×5 Array{Float64,2}:
#  5.03049  4.77469  4.03914  4.25929  5.03992
